# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/program_5_dataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
data.describe()
# Out:
#        Unnamed: 0         Age         ALB         ALP         ALT         AST  \
# count  615.000000  615.000000  613.000000  595.000000  612.000000  613.000000
# mean   308.000000   47.408130   41.622838   68.263529   28.493627   34.731648
# std    177.679487   10.055105    5.784979   26.049129   25.498962   33.090023
# min      1.000000   19.000000   14.900000   11.300000    0.900000   10.600000
# 25%    154.500000   39.000000   38.800000   52.500000   16.400000   21.600000
# 50%    308.000000   47.000000   42.000000   66.200000   23.000000   25.900000
# 75%    461.500000   54.000000   45.200000   80.100000   33.100000   32.900000
# max    615.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  615.000000  615.000000  604.000000   614.000000  615.000000  614.000000
# mean    11.396748    8.196634    5.368013    81.271987   39.533171   72.044137
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            2
# ALP           20
# ALT            3
# AST            2
# BIL            0
# CHE            0
# CHOL          11
# CREA           1
# GGT            0
# PROT           1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  615 non-null    int64
#  1   Category    615 non-null    object
#  2   Age         615 non-null    int64
#  3   Sex         615 non-null    object
#  4   ALB         613 non-null    float64
#  5   ALP         595 non-null    float64
#  6   ALT         612 non-null    float64
#  7   AST         613 non-null    float64
#  8   BIL         615 non-null    float64
#  9   CHE         615 non-null    float64
#  10  CHOL        604 non-null    float64
#  11  CREA        614 non-null    float64
#  12  GGT         615 non-null    float64
#  13  PROT        614 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 67.4+ KB

# %%
mode_value = data['PROT'].mode()[0]
data['PROT'].fillna(mode_value, inplace=True)

# %%
mode_value = data['CREA'].mode()[0]
data['CREA'].fillna(mode_value, inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Category       0
# Age            0
# Sex            0
# ALB            2
# ALP           20
# ALT            3
# AST            2
# BIL            0
# CHE            0
# CHOL          11
# CREA           0
# GGT            0
# PROT           0
# dtype: int64

# %%
x = data[['CREA']]
y = data['PROT']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y,color='hotpink')
plt.xlabel('CREA')
plt.ylabel('PROT')
plt.show()

# %%
# splitting the data into 80:20 (train and test)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
mode_value = data['ALB'].mode()[0]
data['ALB'].fillna(mode_value, inplace=True)
mode_value = data['ALP'].mode()[0]
data['ALP'].fillna(mode_value, inplace=True)
mode_value = data['CHOL'].mode()[0]
data['CHOL'].fillna(mode_value, inplace=True)
mode_value = data['ALT'].mode()[0]
data['ALT'].fillna(mode_value, inplace=True)
mode_value = data['AST'].mode()[0]
data['AST'].fillna(mode_value, inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Category      0
# Age           0
# Sex           0
# ALB           0
# ALP           0
# ALT           0
# AST           0
# BIL           0
# CHE           0
# CHOL          0
# CREA          0
# GGT           0
# PROT          0
# dtype: int64

# %%
import seaborn as sns

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(12,10))
sns.heatmap(correlation_matrix , annot=True , cmap = 'magma')
plt.show()
# Out:
# <ipython-input-36-b7dd6d0ea95b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X_vif = data.drop(columns=['Unnamed: 0','Category', 'Age', 'Sex'])
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(X_vif.shape[1])]

# %%
X_vif
# Out:
#       ALB    ALP    ALT    AST   BIL    CHE  CHOL   CREA    GGT  PROT
# 0    38.5   52.5    7.7   22.1   7.5   6.93  3.23  106.0   12.1  69.0
# 1    38.5   70.3   18.0   24.7   3.9  11.17  4.80   74.0   15.6  76.5
# 2    46.9   74.7   36.2   52.6   6.1   8.84  5.20   86.0   33.2  79.3
# 3    43.2   52.0   30.6   22.6  18.9   7.33  4.74   80.0   33.8  75.7
# 4    39.2   74.1   32.6   24.8   9.6   9.15  4.32   76.0   29.9  68.7
# ..    ...    ...    ...    ...   ...    ...   ...    ...    ...   ...
# 610  32.0  416.6    5.9  110.3  50.0   5.57  6.30   55.7  650.9  68.5
# 611  24.0  102.8    2.9   44.4  20.0   1.54  3.02   63.0   35.9  71.3
# 612  29.0   87.3    3.5   99.0  48.0   1.66  3.63   66.7   64.2  82.0
# 613  33.0   52.5   39.0   62.0  20.0   3.56  4.20   52.0   50.0  71.0
# 614  36.0   52.5  100.0   80.0  12.0   9.07  5.30   67.0   34.0  68.0
#
# [615 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_vif, y, test_size=0.2, random_state=42)
model_multiple = LinearRegression().fit(X_train, y_train)

# %%
import statsmodels.api as sm

# %%
from sklearn.preprocessing import PolynomialFeatures
chosen_attribute = 'CREA'
degrees = [2, 3, 4]
for degree in degrees:
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(data[[chosen_attribute]])
    model_poly = sm.OLS(y, X_poly).fit()

# %%
from sklearn.linear_model import Ridge, Lasso
alpha_values = np.arange(0.1, 150.1, 10)
for alpha in alpha_values:
    ridge_model = Ridge(alpha=alpha).fit(X_train[[chosen_attribute]], y_train)

# %%
alpha_values_lasso = np.arange(0.1, 100.1, 10)
for alpha_lasso in alpha_values_lasso:
    lasso_model = Lasso(alpha=alpha_lasso).fit(X_train[[chosen_attribute]], y_train)

# %%
from sklearn.model_selection import cross_val_score
cross_val_scores = cross_val_score(model_multiple, X_train, y_train, cv=5)

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred_train = model_multiple.predict(X_train)
y_pred_test = model_multiple.predict(X_test)
mse_train = mean_squared_error(y_train, y_pred_train)
mse_test = mean_squared_error(y_test, y_pred_test)
r2_train = r2_score(y_train, y_pred_train)
r2_test = r2_score(y_test, y_pred_test)
mse_train , mse_test , r2_train , r2_test
# Out:
# (2.2524223570212953e-28, 5.7998592992639465e-28, 1.0, 1.0)

# %%
print("Intercept:", model_multiple.intercept_)
print("Coefficient:", model_multiple.coef_)
# Out:
# Intercept: 0.0
# Coefficient: [ 7.29619340e-16  2.22044605e-16  3.18321758e-16 -5.55111512e-17
#   4.16333634e-16 -4.37150316e-16 -6.93889390e-17  9.71445147e-17
#  -2.49800181e-16  1.00000000e+00]

# %% [markdown]
# The model has an intercept of 0.0 and nearly zero coefficients for most features, except the last, which has a coefficient of 1.0. This suggests that the features minimally impact the prediction, except for the last feature, indicating a strong linear relationship with the dependent variable.
